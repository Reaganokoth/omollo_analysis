# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf

import statsmodels.api as sm

# %matplotlib inline

# %%
data_diani = pd.read_csv('Diani_sediment_data.csv')
data_diani
# Out:
#                        Habitat Site name  Average of AGB (g/m2)  \
# 0   Mangrove fringed shoreline    Chale                   0.143
# 1   Mangrove fringed shoreline    Chale                   0.967
# 2   Mangrove fringed shoreline    Chale                   1.050
# 3   Mangrove fringed shoreline    Chale                   0.504
# 4   Mangrove fringed shoreline    Chale                   0.546
# ..                         ...       ...                    ...
# 78              Tourist hotels   Neptune                  2.576
# 79              Tourist hotels   Neptune                 16.912
# 80              Tourist hotels   Neptune                  0.998
# 81              Tourist hotels   Neptune                  1.079
# 82              Tourist hotels   Neptune                  3.829
#
#     AGB (g DW m-2)  AGCorg (Mg C ha-1)  AGCorg (Mg C ha-1).1  \
# 0        50.601557           17.204529              0.172045
# 1       342.179759          116.341118              1.163411
# ...

# %%
data_diani.columns[2]


x = list(data_diani.columns)



x[2] = 'Average_AGB'
x[6] = 'Average_BGB'

data_diani.columns= x
x
# Out:
# ['Habitat',
#  'Site name',
#  'Average_AGB',
#  'AGB (g DW m-2)',
#  'AGCorg (Mg C ha-1)',
#  'AGCorg (Mg C ha-1).1',
#  'Average_BGB',
#  'BGB (g DW m-2)',
#  'BGCorg (Mg C ha-1)',
#  'BGCorg (Mg C ha-1).1']

# %%
data_diani
# Out:
#                        Habitat Site name  Average_AGB  AGB (g DW m-2)  \
# 0   Mangrove fringed shoreline    Chale         0.143       50.601557
# 1   Mangrove fringed shoreline    Chale         0.967      342.179759
# 2   Mangrove fringed shoreline    Chale         1.050      371.549894
# 3   Mangrove fringed shoreline    Chale         0.504      178.343949
# 4   Mangrove fringed shoreline    Chale         0.546      193.205945
# ..                         ...       ...          ...             ...
# 78              Tourist hotels   Neptune        2.576      911.535740
# 79              Tourist hotels   Neptune       16.912     5984.430290
# 80              Tourist hotels   Neptune        0.998      353.149328
# 81              Tourist hotels   Neptune        1.079      381.811748
# 82              Tourist hotels   Neptune        3.829     1354.918613
#
#     AGCorg (Mg C ha-1)  AGCorg (Mg C ha-1).1  Average of BGB (g/m2)  \
# ...

# %% [markdown]
# - Please  Check for variations in sediment, AGB, and BGB among habitats.
#
# - Sediment is on (sed final ), and biomass is on (biomass final).
#
# - Kind regards

# %%
AGB_vs_Habitat = smf.ols(formula='Average_AGB ~ C(Habitat)', data=data_diani).fit()
summary = AGB_vs_Habitat.summary()
print(summary)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            Average_AGB   R-squared:                       0.093
# Model:                            OLS   Adj. R-squared:                  0.059
# Method:                 Least Squares   F-statistic:                     2.708
# Date:                Fri, 05 Aug 2022   Prob (F-statistic):             0.0508
# Time:                        09:44:16   Log-Likelihood:                -193.03
# No. Observations:                  83   AIC:                             394.1
# Df Residuals:                      79   BIC:                             403.7
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# ...

# %%
BGB_vs_Habitat = smf.ols(formula='Average_BGB ~ C(Habitat)', data=data_diani).fit()
summary = BGB_vs_Habitat.summary()
print(summary)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            Average_BGB   R-squared:                       0.119
# Model:                            OLS   Adj. R-squared:                  0.086
# Method:                 Least Squares   F-statistic:                     3.568
# Date:                Fri, 05 Aug 2022   Prob (F-statistic):             0.0177
# Time:                        09:51:07   Log-Likelihood:                -275.49
# No. Observations:                  83   AIC:                             559.0
# Df Residuals:                      79   BIC:                             568.7
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# ...
